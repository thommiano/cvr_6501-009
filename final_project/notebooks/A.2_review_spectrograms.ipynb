# %%
import matplotlib.pyplot as plt

import torch
from torch.autograd import Variable

import numpy as np

import sys
sys.path.append("/audio")
import torchaudio

import os
from PIL import Image

# %matplotlib inline

# %%
def dir_avg(src_path):
    '''Generate the average image given a directory of images.'''
    
    # Access all PNG files in directory
    allfiles=os.listdir(src_path)
    imlist=[filename for filename in allfiles if  filename[-4:] in [".jpg",".JPG"]]
    
    # Assuming all images are the same size, get dimensions of first image
    img_open = ''.join([src_path,imlist[0]])
    w,h=Image.open(img_open).size
    N=len(imlist)
    
    # Create a numpy array of floats to store the average (assume RGB images)
    arr=np.zeros((h,w,3),np.float)
    
    # Build up average pixel intensities, casting each image as an array of floats
    for im in imlist:
        img_open = ''.join([src_path,im])
        imarr=np.array(Image.open(img_open),dtype=np.float)
        arr=arr+imarr/N
    
    # Round values in array and cast as 8-bit integer
    arr=np.array(np.round(arr),dtype=np.uint8)
    
    return arr

# %% [markdown]
# # Gun shot

# %%
src_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image_80tr10va10te/trainset/gun_shot/"
avg_img = dir_avg(src_path)

# %%
plt.imshow(avg_img)

# %% [markdown]
# ### Street music

# %%
src_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image/trainset/street_music/"
avg_img = dir_avg(src_path)

# %%
plt.imshow(avg_img)

# %%
test_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image/trainset/street_music/101848-9-0-0.jpg"
img = Image.open(test_path)
plt.imshow(img)

# %%
test_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image/trainset/street_music/108638-9-0-5.jpg"
img = Image.open(test_path)
plt.imshow(img)

# %% [markdown]
# ### Children playing

# %%
src_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image/trainset/children_playing/"
avg_img = dir_avg(src_path)

# %%
plt.imshow(avg_img)

# %%
test_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image/trainset/children_playing/100263-2-0-117.jpg"
img = Image.open(test_path)
plt.imshow(img)

# %%
test_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image/trainset/children_playing/182800-2-2-2.jpg"
img = Image.open(test_path)
plt.imshow(img)

# %% [markdown]
# ### Dog bark

# %%
src_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image/trainset/dog_bark/"
avg_img = dir_avg(src_path)

# %%
plt.imshow(avg_img)

# %%
test_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image/trainset/dog_bark/100652-3-0-1.jpg"
img = Image.open(test_path)
plt.imshow(img)

# %%
test_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image/trainset/dog_bark/194754-3-0-1.jpg"
img = Image.open(test_path)
plt.imshow(img)

# %%
# First one had problems because of number of mel
# test_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image/trainset/dog_bark/194754-3-0-1.png"
# img = Image.open(test_path)
# plt.imshow(img)

# %% [markdown]
# ### Drilling

# %%
src_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image/trainset/drilling/"
avg_img = dir_avg(src_path)

# %%
plt.imshow(avg_img)

# %%
test_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image/trainset/drilling/118278-4-0-0.jpg"
img = Image.open(test_path)
plt.imshow(img)

# %%
test_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image/trainset/drilling/165785-4-3-0.jpg"
img = Image.open(test_path)
plt.imshow(img)

# %% [markdown]
# # Examine channels

# %%
test_path = "/data/datasets/sound_datasets/pytorch_UrbanSound8K/image_80tr10va10te/trainset/children_playing/60935-2-0-9.jpg"
img = Image.open(test_path)
plt.imshow(img)
plt.tight_layout()

# %%
img_arr = np.array(img)
img_arr.shape
# Out:
# (440, 600, 3)

# %%
plt.figure(figsize=(16, 8))

plt.subplot(1,3,1)
plt.imshow(img_arr[:,:,0],cmap='Reds')
plt.title("Red channel")
plt.subplot(1,3,2)
plt.imshow(img_arr[:,:,1],cmap='Greens')
plt.title("Green channel")
plt.subplot(1,3,3)
plt.imshow(img_arr[:,:,2],cmap='Blues')
plt.title("Blue channel")

plt.tight_layout()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
